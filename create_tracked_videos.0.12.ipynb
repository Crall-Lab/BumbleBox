# %%
import cv2
from cv2 import aruco
import numpy as np
import math
import time
import os
import sys
#from IPython.display import clear_output
#import multiprocessing
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
import traceback
#import matplotlib as mpl
import pandas as pd
#%matplotlib nbagg

# %%
def make_complementary_color_bgr(somecolor=type(tuple)):

    complementary_color = [0,0,0]
    for i in range(len(somecolor)):
        complementary_color[i] = 255 - somecolor[i]
    
    complementary_color = tuple(complementary_color)

    return complementary_color

# %%
def create_tag_list(df):
    try:
        tag_list = list(df['ID'].unique())
        print("tag_list object created")
        print(tag_list)
        return tag_list
    except:
        print("Check out your csv file, does it have bees in it? Ie does it have a \'ID\' column?")
        return None

# %%
def create_tag_colors(tag_colors, tag_list):
    if isinstance(tag_colors, type(None)): 
            if not isinstance(tag_list, type(None)) and len(tag_list) > 0:
                cm = plt.get_cmap('rainbow') # or 'gist_rainbow'
                cNorm  = colors.Normalize(vmin=0, vmax=len(tag_list)-1)
                scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
                color_palette=[scalarMap.to_rgba(i, bytes=True) for i in range(len(tag_list))]
                tag_colors = pd.Series(color_palette, index=tag_list)
                return tag_colors
            else:
                print("Had an issue setting the colors for the tags...")
                return None
            
    else:
         if len(tag_colors) == len(tag_list):
            return tag_colors
         
         else:
            print("Had an issue setting the colors for the tags...")
            return None

# %%
def create_bee_pairs_list(tag_list):
    if len(tag_list) > 0:
        bee_pairs = [(a, b) for idx, a in enumerate(tag_list) for b in tag_list[idx + 1:]] # splits list into all its pair combinations. Ex list [3,4,5] becomes [(3,4),(3,5),(4,5)]
        return bee_pairs

# %%
def create_line_colors(line_colors, bee_pairs):

    if len(bee_pairs) > 0:

        if isinstance(line_colors, type(None)): 

            cm1 = plt.get_cmap('gist_earth') # or 'gist_rainbow'
            cNorm1  = colors.Normalize(vmin=0, vmax=len(bee_pairs)-1)
            scalarMap1 = mplcm.ScalarMappable(norm=cNorm1, cmap=cm1)
            color_palette1=[scalarMap1.to_rgba(i, bytes=True) for i in range(len(bee_pairs))]
            line_colors = pd.Series(color_palette1, index=bee_pairs)
            return line_colors
        
        elif len(line_colors) == len(bee_pairs):
            return line_colors

        else:
            print("Had an issue setting the colors for the distance lines between bees...")
            return None
    else:
        print("No bee pairs to create line colors for...")
        return None

# %%
def extract_filename(video_path):
    file_dir, file = os.path.split(video_path)
    filename, extension = os.path.splitext(file)
    print(filename)
    return filename, extension

# %%
def extract_size(vid):
    print("write_video is on")
    frame_width = int(vid.get(3))
    frame_height = int(vid.get(4))
    size = (frame_width, frame_height)
    return size

# %%
def create_outputfile_and_videowriter(tracked_video_destination_directory, filename, video_filename_addition, extension, playback_framerate, size):

    if video_filename_addition == None:
            video_filename_addition = ''
            
    if extension == '.mjpeg':
        output_file = "{0}{1}{2}{3}".format(tracked_video_destination_directory, filename, video_filename_addition, '.mjpeg')
        print(output_file)
        out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc('m','j','p','g'), playback_framerate, size) # .format(tracked_video_destination_directory, filename, video_filename_addition)
        return out
    
    elif extension == '.mp4':
        output_file = "{0}{1}{2}{3}".format(tracked_video_destination_directory, filename, video_filename_addition, '.mp4')
        print(output_file)
        out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc('m','p','4','v'), playback_framerate, size)
        return out
    
    else:
        print("This script can only process mjpeg and mp4 files")
        return None

# %%
def find_bee_pair_coordinates(i, bee_pairs, frame_ids, frame_df):

    bee1=bee_pairs[i][0]
    bee2=bee_pairs[i][1]
    
    if bee1 in frame_ids and bee2 in frame_ids:
        bee1row = frame_df[ frame_df['ID']== bee1 ]
        xmeanbee1 = bee1row['centroidX']
        xmeanbee1 = int(xmeanbee1.iloc[0])
        ymeanbee1 = bee1row['centroidY']
        ymeanbee1 = int(ymeanbee1.iloc[0])

        bee1_loc = (xmeanbee1, ymeanbee1)
        
        bee2row = frame_df[ frame_df['ID']== bee2 ]
        xmeanbee2 = bee2row['centroidX']
        xmeanbee2 = int(xmeanbee2.iloc[0])
        ymeanbee2 = bee2row['centroidY']
        ymeanbee2 = int(ymeanbee2.iloc[0])

        bee2_loc = (xmeanbee2, ymeanbee2)

        distance = math.sqrt( ((xmeanbee1-xmeanbee2)**2)+((ymeanbee1-ymeanbee2)**2) )

        return bee1, bee2, bee1_loc, bee2_loc, distance
    
    else:
        return bee1, bee2, None, None, None

# %%
def draw_bee_lines(i, pairwise_focal_bee, focal_bee_coord, bee1, bee2, bee1_loc, bee2_loc, pairwise_line_size, focal_bee_color, background_bee_color, line_colors, bee_pairs, frame, frame_num, pairwise_trail, pairwise_trail_list, focal_bee_container, distance, contacts, contact_distance, contacts_container, queen_id, queen_contact_distance):
    
    #Limit tracking bee lines to a certain distance between bees
    if distance > 800:
        return frame, focal_bee_coord, focal_bee_container, pairwise_trail_list, contacts_container
    #first check if bees are in contact with each other. If yes, store the result and exit the function - these lines will be drawn later (on top of other lines)
    if contacts == 'ON':
        
        if int(bee1) == int(queen_id) or int(bee2) == int(queen_id):
            #print(f"Making contact distance ({contact_distance}) queen contact distance: {queen_contact_distance}")
            contact_distance = queen_contact_distance
            #print(f"New contact distance: {contact_distance}")
            
        else:
            contact_distance = contact_distance

        if distance <= contact_distance:
            #if bee1 == 17 or bee2 == 17:
            print("Contact between bees {0} and {1} at frame {2}: distance is {3}, contact distance is {4}".format(bee1, bee2, frame_num, distance, contact_distance))
            contacts_container.append([bee1, bee2, bee1_loc, bee2_loc])
            return frame, focal_bee_coord, focal_bee_container, pairwise_trail_list, contacts_container


    #Next, if we are tracking a focal bee for pairwise distance tracking, check if its either of the current pairs
    if type(pairwise_focal_bee) == int:
        if bee1 == pairwise_focal_bee and focal_bee_coord == None:
            focal_bee_coord = bee1_loc 

        elif bee2 == pairwise_focal_bee and focal_bee_coord == None:
            focal_bee_coord = bee2_loc

        #if either is the focal bee, store the data to be drawn later (on top of other lines, but before the contact lines)
        if bee1 == pairwise_focal_bee or bee2 == pairwise_focal_bee:
            focal_bee_container.append([bee1_loc, bee2_loc, focal_bee_color, pairwise_line_size]) #add to list so that they're tracked on last, ie will be on top

        #if neither is the focal bee, draw the lines with the background bee color    
        else:
            cv2.line(frame, bee1_loc, bee2_loc, background_bee_color, pairwise_line_size)

    #if we are not tracking a focal bee, draw the normal line colors for that bee pair
    else:
        line_color = line_colors[bee_pairs[i]]
        line_color_rgb = ( int(line_color[0]), int(line_color[1]), int(line_color[2]) )

        if pairwise_trail == 'ON':
            pairwise_trail_list.append([frame_num, bee1_loc, bee2_loc, line_color_rgb, pairwise_line_size]) # append current line to list

        else:
            cv2.line(frame, bee1_loc, bee2_loc, line_color_rgb, pairwise_line_size)

    return frame, focal_bee_coord, focal_bee_container, pairwise_trail_list, contacts_container

# %%
def plot_focal_bee_lines(frame, focal_bee_container, focal_bee_coord, focal_bee_color, avg_distance_vector, avg_distance_vector_color):

    avg_distance_vector_data = []
    for row in focal_bee_container:
        cv2.line(frame, row[0], row[1], row[2], row[3]) # row = [bee1_loc, bee2_loc, line_color_rgb, line size]

        # if plotting the avg distance vector, finds the bees coordinates that arent the focal bee in the focal_bee_container
        if avg_distance_vector == 'ON':
            if row[0] == focal_bee_coord:
                avg_distance_vector_data.append([row[1]])
                
            elif row[1] == focal_bee_coord:
                avg_distance_vector_data.append([row[0]])

    # if plotting the avg dinstance vector, finds the average coordinates of all other bees 
    if avg_distance_vector == 'ON':
        print(avg_distance_vector_data)
        avg_dvd_nparray = np.array(avg_distance_vector_data)

        # below code removes the 2nd dimension that is equal to 1 (this is an uneccesary dimension for us), in this case will make it array go from (x, 1, z) to (x,y)

        if avg_dvd_nparray.shape[0] != 1: # if more than just one set of coordinates in avg_distance_vector_data...
            #print('using np.squeeze...')
            #print(avg_dvd_nparray)
            #print(avg_dvd_nparray.shape)
            avg_dvd_nparray = avg_dvd_nparray.squeeze() # removes and dimension equal to 1 (this is an uneccesary dimension for us), in this case will make it array go from (x, 1, z) to (x,y)
            #print(avg_dvd_nparray.shape)
        else:                             # if only one set of coordinates in avg_distance_vector_data
            print('shouldnt use np.squeeze...')
            print(avg_dvd_nparray)
            print(avg_dvd_nparray.shape)
            x_column = avg_dvd_nparray[0][0][0]
            y_column = avg_dvd_nparray[0][0][1]
            avg_dvd_nparray = np.column_stack((x_column, y_column))
            print(avg_dvd_nparray)
            print(avg_dvd_nparray.shape)
    
        # removes and dimension equal to 1 (this is an uneccesary dimension for us), in this case will make it array go from (x, 1, z) to (x,y)
        # note - got this error for the below line: Exception: too many indices for array: array is 1-dimensional, but 2 were indexed, Type: <class 'IndexError'>, line number: 144
        avg_dv_x = np.mean(avg_dvd_nparray[:,0])
        avg_dv_y = np.mean(avg_dvd_nparray[:,1])
        avg_dv_xy = (int(avg_dv_x), int(avg_dv_y))
        if avg_distance_vector_color == 'complementary':
            complementary = make_complementary_color_bgr(focal_bee_color) # use the complement color in bgr space to plot the average distance vector per frame
            cv2.arrowedLine(frame, focal_bee_coord, avg_dv_xy, complementary, 15, tipLength=0.05)
        else:
            cv2.arrowedLine(frame, focal_bee_coord, avg_dv_xy, avg_distance_vector_color, 15, tipLength=0.05)

    return frame

# %%
def draw_pairwise_trail_lines(frame, pairwise_trail_list, frame_num):
    for row in pairwise_trail_list:
        if frame_num - row[0] < 10: # draw lines over the past 10 frames
            # row = [bee1_loc, bee2_loc, line_color_rgb, line size]
            cv2.line( frame, row[1], row[2], row[3], row[4] )
    
    return frame

# %%
def draw_contact_lines(contacts_container, contacts_color, contacts_line_size, enable_contacts_alpha_channel, contacts_alpha, frame, updated_frame_copy):
    
    for contact in contacts_container: # contact row = [bee1, bee2, bee1_loc, bee2_loc]
        if contact[0] == 17 or contact[1] == 17:
            print("contact for bee 17")
        cv2.line(frame, contact[2], contact[3], contacts_color, contacts_line_size)

    #Addweighted uses the alpha value to blend the image with the contacts drawn on top of it to an image saved just prior to the contacts being drawn
    if enable_contacts_alpha_channel == 'ON':
        frame = cv2.addWeighted(frame, contacts_alpha, updated_frame_copy, 1 - contacts_alpha, 0)
    
    return frame

# %%
def draw_ids(frame, id, frame_df, tag_list, tag_colors, contacts, contacts_container, contacts_color):

    if tag_list != None and id in tag_list: #at this point tag_list should have a value, even if originally set to None
        #find id x and y coordinates
        id_row = frame_df[ frame_df['ID'] == id ]
        xmean = id_row['centroidX'] #int(ser.iloc[0])
        xmean = int(xmean.iloc[0])
        ymean = id_row['centroidY']
        ymean = int(ymean.iloc[0])

        bee_color = tag_colors[id]
        bee_color_rgb = ( int(bee_color[0]), int(bee_color[1]), int(bee_color[2]) )
    
        #if contacts are on, Determine whether bee is in contact with another bee
        in_contact = False
        if contacts == 'ON':
            for contact in contacts_container:
                if id == contact[0] or id == contact[1]:
                    in_contact = True
                    break
            
            if in_contact == True:
                font = cv2.FONT_HERSHEY_SIMPLEX
                org = (xmean - 40, ymean - 20)
                fontScale = 2
                thickness = 3
                frame = cv2.putText(frame, str(id), org, font, fontScale, (0,0,0), thickness*2, cv2.LINE_AA) #create a black border around text (w doubled thickness)
                frame = cv2.putText(frame, str(id), org, font, fontScale, contacts_color, thickness, cv2.LINE_AA)
            
            else:
                font = cv2.FONT_HERSHEY_SIMPLEX
                org = (xmean - 40, ymean - 20)
                fontScale = 2
                color = bee_color_rgb
                thickness = 3
                frame = cv2.putText(frame, str(id), org, font, fontScale, (0,0,0), thickness*2, cv2.LINE_AA) #create a black border around text (w doubled thickness)
                frame = cv2.putText(frame, str(id), org, font, fontScale, color, thickness, cv2.LINE_AA)

        else:
            font = cv2.FONT_HERSHEY_SIMPLEX
            org = (xmean - 40, ymean - 20)
            fontScale = 2
            color = bee_color_rgb
            thickness = 3
            frame = cv2.putText(frame, str(id), org, font, fontScale, (0,0,0), thickness*2, cv2.LINE_AA) #create a black border around text (w doubled thickness)
            frame = cv2.putText(frame, str(id), org, font, fontScale, color, thickness, cv2.LINE_AA)

        return frame
    
    else:
        print("id not in tag_list or tag list None")
        return frame

# %%
def draw_centroids_and_tracking_trails(frame, id, tag_list, frame_df, tracking_trail, tracking_trail_dict, tag_colors, frame_num, contacts, contacts_color, non_contact_color, contacts_container ):
    
    frame_copy = frame.copy()
    
    if tag_list != None and id in tag_list: #at this point tag_list should have a value, even if originally set to None
        #find id x and y coordinates
        id_row = frame_df[ frame_df['ID'] == id ]
        xmean = id_row['centroidX'] #int(ser.iloc[0])
        xmean = int(xmean.iloc[0])
        ymean = id_row['centroidY']
        ymean = int(ymean.iloc[0])
    
        frame_index = str(id) + '_index'
        if id not in tracking_trail_dict.keys():
            tracking_trail_dict[id] = [(xmean, ymean)]
            tracking_trail_dict[frame_index] = [frame_num]
        else:
            tracking_trail_dict[id] += [(xmean, ymean)]
            tracking_trail_dict[frame_index] += [frame_num]

        #if contacts are on, Determine whether bee is in contact with another bee
        in_contact = False
        if contacts == 'ON':
            for contact in contacts_container:
                if id == contact[0] or id == contact[1]:
                    in_contact = True
                    break

#end visualizing tag ids
# start visualizing tag dots (and trails if applicable)                           

        bee_color = tag_colors[id]
        bee_color_rgb = ( int(bee_color[0]), int(bee_color[1]), int(bee_color[2]) )

        if contacts == 'ON':
            bee_color_rgb = non_contact_color

#start of code to draw lines between tags detected in the last 10 frames

        if tracking_trail == 'ON':
            trail = tracking_trail_dict[id] # save data associated with tag id in the dictionary
            trail_index = tracking_trail_dict[frame_index]
            for i in range(len(trail)):
                if (frame_num - trail_index[i]) < 11: # if current frame - frame i is less than 11
                    trail = trail[i:] # reassign trail the subset of trail data from row i onwards
                    trail_index = trail_index[i:] # reassign trail_index the subset of trail_index data from row i onwards
                    break
            
            #We want the tracking trail to diminish in intensity the further away from the current frame it is
            #So we're assigning an alpha value to each frame in the trail based on its distance from the current frame
            alpha_values = {9: 0.1, 8: 0.2, 7: 0.3, 6: 0.4, 5: 0.5, 4: 0.6, 3: 0.7, 2: 0.8, 1: 0.9, 0: 1.0}
            
            for i in range(len(trail)):
                if i == 0:
                    continue
                print(i)

                #if tracking trail and contacts are on and the current tag id is in the contacts container, draw the dot in the contacts color
                if contacts == 'ON' and in_contact == True:
                    cv2.line(frame, trail[i-1], trail[i], bee_color_rgb, 8)
                    cv2.circle(frame, tuple([int(xmean), int(ymean)]), 20, contacts_color, -1)
                else:
                    #Based on the distance of the frame from the current frame, assign it the appropriate alpha value
                    print(f"trail_index[i]: {trail_index[i]}")
                    print(f"frame_num: {frame_num}")
                    frame_distance = frame_num - trail_index[i]
                    print(f"frame distance: {frame_distance}")
                    print(f"alpha_value: {alpha_values[frame_distance]}")
                    alpha = alpha_values[frame_distance]

                    cv2.line(frame, trail[i-1], trail[i], bee_color_rgb, 8)
                    cv2.circle(frame, tuple([int(xmean), int(ymean)]), 20, bee_color_rgb, -1)
                    frame = cv2.addWeighted(frame, alpha, frame_copy, 1 - alpha, 0)

        elif contacts == 'ON' and in_contact == True:
            cv2.circle(frame, tuple([int(xmean), int(ymean)]), 20, contacts_color, -1)
                
        else:
            cv2.circle(frame, tuple([int(xmean), int(ymean)]), 20, bee_color_rgb, -1)

        return frame, tracking_trail_dict

# %%
def print_error_message(e):
    traceback.print_exc()
    exc_type, exc_obj, exc_tb = sys.exc_info()
    print("Exception: {}, Type: {}, line number: {}".format(e, exc_type, exc_tb.tb_lineno)) #exc_type, exc_obj, exc_tb.tb_lineno
    print("issue detecting markers")

# %%
# switched variable name to show_video - need to change this in other scripts!
def write_tags_onto_video(csv_path, video_path, tracked_video_destination_directory, playback_framerate=10,
                                                                                     show_video='ON', 
                                                                                     write_video='ON',  
                                                                                     tracking_trail='OFF',
                                                                                     pairwise_distance_tracking='OFF',
                                                                                     pairwise_trail='OFF',
                                                                                     pairwise_focal_bee=None,
                                                                                     pairwise_line_size=4,
                                                                                     enable_pairwise_alpha_channel='OFF',
                                                                                     pairwise_alpha=0.6,
                                                                                     focal_bee_color=None,
                                                                                     background_bee_color=None,
                                                                                     contacts = 'OFF',
                                                                                     contact_distance=200,
                                                                                     queen_id=1,
                                                                                     queen_contact_distance=None,
                                                                                     contacts_color=None,
                                                                                     non_contact_color=None,
                                                                                     contacts_line_size=6,
                                                                                     enable_contacts_alpha_channel='OFF',
                                                                                     contacts_alpha=0.8,
                                                                                     avg_distance_vector='OFF',
                                                                                     avg_distance_vector_color='complementary',
                                                                                     tag_list = None,
                                                                                     tag_colors = None,
                                                                                     line_colors = None, 
                                                                                     video_filename_addition=None ):
    #read in csv data and video
    df = pd.read_csv(csv_path)
    vid = cv2.VideoCapture(video_path)

    #create tag list from csv data if none is provided
    if tag_list == None:
        tag_list = create_tag_list(df)
    #create tag colors if none are provided or if the length of the tag list is different from the length of the tag colors list
    if show_video == 'ON' or write_video == 'ON':
        tag_colors = create_tag_colors(tag_colors, tag_list)
        
        #create bee pairs list and colors if pairwise distance tracking is on
        if pairwise_distance_tracking == 'ON':
            bee_pairs = create_bee_pairs_list(tag_list)
            line_colors = create_line_colors(line_colors, bee_pairs)

    else:
        print("show_video is 'OFF\'")
   
    #extract filename and extension from video path
    filename, extension = extract_filename(video_path)

    #if write_video is on, extract size of video and create output file and video writer
    if write_video == 'ON':
        size = extract_size(vid)
        out = create_outputfile_and_videowriter(tracked_video_destination_directory, filename, video_filename_addition, extension, playback_framerate, size)


    #initialize variables in preparation for looping over frames in the video
    #one for storing the tracking trails, one for storing pairwise distances, and one for the frame number
    tracking_trail_dict = {}
    pairwise_trail_list = []
    frame_num = 0


    while(vid.isOpened()):
        ret, frame = vid.read() #ret stores boolean, frame stores the frame -code copied
        
        if ret == True:
            try:
                #store the original frame for later use when applying alpha blending
                frame_original = frame.copy()
                #This if statements lets you know you have to set one of these to ON         
                if write_video == 'ON' or show_video == 'ON':

                    #grabs the frame dataframe and the frame ids specifically 
                    frame_df = df[ df['frame'] == frame_num ]
                    frame_ids = frame_df['ID'].unique()

                    # draw connecting lines between bees in tag_list if pairwise_distance_tracking is ON
                    # if tracking_trail is on, have these lines persist for maybe five frames?
                    # I put this distance tracking code first so that the tag numbers and dots are drawn over the connecting lines
                    # this way they're seen more clearly
                    focal_bee_container = [] # will be updated to capture coordinates of focal bee and other tracked bee, in order to draw line between them
                    focal_bee_coord = None # will be updated to capture the coordinates of just the focal bee
                    contacts_container = [] # will be updated to capture the coordinates of bees that are in contact with each other

                    #To enter following code block, write or show video is set to on, and pairwise tracking is set to on
                    if pairwise_distance_tracking == 'ON':

                        for i in range(len(bee_pairs)):
                            bee1, bee2, bee1_loc, bee2_loc, distance = find_bee_pair_coordinates(i, bee_pairs, frame_ids, frame_df)

                            if bee1_loc != None and bee2_loc != None:
                                frame, focal_bee_coord, focal_bee_container, pairwise_trail_list, contacts_container = draw_bee_lines(i, pairwise_focal_bee, focal_bee_coord, bee1, bee2, bee1_loc, bee2_loc, pairwise_line_size, focal_bee_color, background_bee_color, line_colors, bee_pairs, frame, frame_num, pairwise_trail, pairwise_trail_list, focal_bee_container, distance, contacts, contact_distance, contacts_container, queen_id, queen_contact_distance)
                                
                        #Only plot the focal bee lines if there is a focal bee ID (its not set to 'OFF'), it's been tracked, and there are other tracked bees in the frame
                        if type(pairwise_focal_bee) == int and len(focal_bee_container) > 0: # only plot lines and calculate average distance vector if focal_bee is on and the focal bee and at least one other bee are tracked in the image
                            
                            frame = plot_focal_bee_lines(frame, focal_bee_container, focal_bee_coord, focal_bee_color, avg_distance_vector, avg_distance_vector_color)

                        #Only runs if you want a trail of pairwise tracks, and not just the lines between bees in the current frame - honestly doesnt look so great
                        if pairwise_trail == 'ON':            
                            frame = draw_pairwise_trail_lines(frame, pairwise_trail_list, frame_num)

                        #Add alpha blending to the frame if pairwise alpha is on, and save updated frame copy so we can add an alpha channel to the contacts lines
                        if enable_pairwise_alpha_channel == 'ON':
                            frame = cv2.addWeighted(frame, pairwise_alpha, frame_original, 1 - pairwise_alpha, 0)
                            updated_frame_copy = frame.copy()

                        #Draw the lines between contacting bees on top of all other lines
                        if contacts == 'ON':
                            frame = draw_contact_lines(contacts_container, contacts_color, contacts_line_size, enable_contacts_alpha_channel, contacts_alpha, frame, updated_frame_copy)

                    #Now we draw the tag ids, centroids, and tracking trails if its on
                    for id in frame_ids:
                        frame, tracking_trail_dict = draw_centroids_and_tracking_trails(frame, id, tag_list, frame_df, tracking_trail, tracking_trail_dict, tag_colors, frame_num, contacts, contacts_color, non_contact_color, contacts_container )
                        if contacts == "ON":
                            continue
                        frame = draw_ids(frame, id, frame_df, tag_list, tag_colors, contacts, contacts_container, contacts_color)
                else:
                    print('Both write_video and show_video are \'OFF\'')

            except Exception as e:
                print_error_message(e)





            #now just writing and showing the frame
            if write_video == 'ON':
                out.write(frame)

            if show_video == 'ON':
                cv2.imshow("Let's track these bees! Beep boop", frame)
    
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            else:
                cv2.waitKey(1)
            
            frame_num += 1

        #if ret is false, ie no more frames to read, break out of loop
        else:
            frame_num += 1
            break




    # Release everything once job is finished
    print("Done! Frames should be written to video.")
    vid.release()
    cv2.destroyAllWindows()

    return tag_colors, line_colors

# %%
#ATTENTION: This code works for MP4 and MJPEG video formats. If you have a different format, you may need to change the video writer codec and format.

csv_path = "/home/august/Desktop/Human Footprint/bumblebox-17_2025-02-14_17_30_03_tracking_interpolated_v2.csv"
video_path = '/home/august/Desktop/Human Footprint/bumblebox-17_2025-02-14_17_30_03.mp4'
tag_list = None #[22, 48, 43, 18, 32, 9, 25, 17, 40, 28, 11, 37, 24, 15, 42, 21, 30, 6, 31, 8, 2, 49, 0, 7, 35, 20, 19] # if None, it will track all tags
tag_colors = None #full_colony_colors #[(139,71,31,55),(),(),(),()] #full_colony_colors
show_video = 'OFF'
tracking_trail = 'OFF'
pairwise_distance_tracking = 'ON'
pairwise_trail = 'OFF'
line_colors = None

pairwise_focal_bee = 1 #'ON' # 'OFF' or tag number of focal bee, ex. 12
pairwise_line_size = 4
enable_pairwise_alpha_channel = 'ON'
pairwise_alpha = 0.3
focal_bee_color = (180,130,70)#(240,32,160) #(255, 100, 50, 150) #B,G,R #trying to add alpha #was (255, 50, 50)
background_bee_color = (180,130,70) # make this gray?

avg_distance_vector='OFF'
avg_distance_vector_color = (0,0,139) # possible values: 'complementary' (complementary to focal bee color), or some BGR color, ex (255, 255, 255), which is white 

contacts = 'ON' # With contacts on, lines will be drawn between bees that are within the contact distance
contact_distance = 175 # 150.4 #distance in pixels that is considered contact between two bees
queen_id = 0
queen_contact_distance = contact_distance * 1.35
contacts_color = (0, 0, 255) # BGR color for the contact lines
non_contact_color = (180,130,70)
contacts_line_size = 5
enable_contacts_alpha_channel = 'OFF' # If contacts are on, do you want to add an alpha channel to the contact lines to control how visible they are?
contacts_alpha = 0.9

write_video = 'ON' # Would you like to write the tracked frames that are displayed into a video? In order to write to a video, show_vid must be 'ON' - the only supported format at the moment is .mjpeg
video_filename_addition = '_distance_limit_v2' # If you're creating a video with tags tracked in it, what info do you want to add to your new filename to distinguish it from the video filename we're tracking? The default is to add '_tracked' to the end. For example, "col_20-2021-01-23_14-00-00.mjpeg" would become "col_20-2021-01-23_14-00-00_tracked.mjpeg"
#video_format = 'MP4' # tested with 'MJPEG' and 'MP4', the code will choose 'MJPEG' if nothing is specified - IF YOU SEE THIS ERROR: " OpenCV: FFMPEG: tag 0x67706a6d/'mjpg' is not supported with codec id 7 and format 'mjpeg / raw MJPEG video' " - check if the file was made, it worked for me on a Mac despite giving me this warning. If it doesn't work, try 'MP4'!
tracked_video_destination_directory = f"{os.path.dirname(video_path)}/" #Add a forward slash to the end of the video directory path
playback_framerate = 6

tag_id_colors = write_tags_onto_video(csv_path, video_path, tracked_video_destination_directory, playback_framerate=playback_framerate, 
                                                                                    show_video=show_video, 
                                                                                    write_video=write_video,  
                                                                                    tracking_trail=tracking_trail,
                                                                                    tag_list=tag_list,
                                                                                    tag_colors=tag_colors,
                                                                                    pairwise_distance_tracking=pairwise_distance_tracking,
                                                                                    line_colors=line_colors,
                                                                                    pairwise_trail=pairwise_trail,
                                                                                    pairwise_focal_bee=pairwise_focal_bee,
                                                                                    pairwise_line_size=pairwise_line_size,
                                                                                    enable_pairwise_alpha_channel=enable_pairwise_alpha_channel,
                                                                                    pairwise_alpha=pairwise_alpha,
                                                                                    focal_bee_color=focal_bee_color,
                                                                                    avg_distance_vector=avg_distance_vector,
                                                                                    avg_distance_vector_color=avg_distance_vector_color,
                                                                                    background_bee_color=background_bee_color,
                                                                                    contacts=contacts,
                                                         #initialize variables in preparation for looping over frames in the video
    #one for storing the tracking trails, one for storing pairwise distances, and one for the frame number
                                                                                    contact_distance=contact_distance,
                                                                                    queen_id=queen_id,
                                                                                    queen_contact_distance=queen_contact_distance,
                                                                                    contacts_color=contacts_color,
                                                                                    non_contact_color=non_contact_color,
                                                                                    contacts_line_size=contacts_line_size,
                                                                                    enable_contacts_alpha_channel=enable_contacts_alpha_channel,
                                                                                    contacts_alpha=contacts_alpha, 
                                                                                    video_filename_addition=video_filename_addition )
# Out:
# tag_list object created
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(13), np.int64(14), np.int64(15), np.int64(17), np.int64(18), np.int64(20), np.int64(21), np.int64(22), np.int64(24), np.int64(25), np.int64(26), np.int64(31), np.int64(32), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(49)]
# bumblebox-17_2025-02-14_17_30_03
# write_video is on
# /home/august/Desktop/Human Footprint/bumblebox-17_2025-02-14_17_30_03_distance_limit_v2.mp4
# Contact between bees 0 and 38 at frame 0: distance is 228.60008748904713, contact distance is 236.25000000000003
# Contact between bees 9 and 41 at frame 0: distance is 141.59802258506295, contact distance is 175
# Contact between bees 13 and 46 at frame 0: distance is 156.01281998605114, contact distance is 175
# Contact between bees 18 and 25 at frame 0: distance is 112.27199116431488, contact distance is 175
# Contact between bees 26 and 31 at frame 0: distance is 146.86047800548656, contact distance is 175
# Contact between bees 36 and 41 at frame 0: distance is 165.71059109181888, contact distance is 175
# Contact between bees 37 and 42 at frame 0: distance is 135.63554106501732, contact distance is 175
# Contact between bees 9 and 41 at frame 1: distance is 112.92475370794483, contact distance is 175
# Contact between bees 13 and 46 at frame 1: distance is 170.98830369355676, contact distance is 175
# Contact between bees 26 and 31 at frame 1: distance is 138.7155362603627, contact distance is 175
# Contact between bees 37 and 40 at frame 1: distance is 142.3938200906205, contact distance is 175
# Contact between bees 37 and 42 at frame 1: distance is 161.75598906995685, contact distance is 175
# Contact between bees 9 and 41 at frame 2: distance is 134.6476884316994, contact distance is 175
# Contact between bees 13 and 46 at frame 2: distance is 173.95401691251627, contact distance is 175
# Contact between bees 26 and 31 at frame 2: distance is 148.67750334196495, contact distance is 175
# Contact between bees 36 and 39 at frame 2: distance is 160.63934760823702, contact distance is 175
# Contact between bees 37 and 40 at frame 2: distance is 151.0, contact distance is 175
# Contact between bees 9 and 41 at frame 3: distance is 153.0294089382822, contact distance is 175
# Contact between bees 15 and 39 at frame 3: distance is 142.23923509355637, contact distance is 175
# Contact between bees 26 and 31 at frame 3: distance is 148.85227576359054, contact distance is 175
# Contact between bees 37 and 40 at frame 3: distance is 172.74258305351347, contact distance is 175
# Contact between bees 38 and 44 at frame 3: distance is 171.4322023425004, contact distance is 175
# Contact between bees 15 and 39 at frame 4: distance is 120.28299963003916, contact distance is 175
# Contact between bees 26 and 31 at frame 4: distance is 148.78844041120936, contact distance is 175
# Contact between bees 37 and 40 at frame 4: distance is 172.16561793807728, contact distance is 175
# Contact between bees 0 and 17 at frame 5: distance is 232.31228981696168, contact distance is 236.25000000000003
# Contact between bees 15 and 39 at frame 5: distance is 128.8875478857442, contact distance is 175
# Contact between bees 26 and 31 at frame 5: distance is 152.9477034806342, contact distance is 175
# Contact between bees 36 and 39 at frame 5: distance is 169.62311163281967, contact distance is 175
# Contact between bees 37 and 40 at frame 5: distance is 164.01219466856725, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 6: distance is 234.1644721130855, contact distance is 236.25000000000003
# Contact between bees 15 and 39 at frame 6: distance is 122.01639234135715, contact distance is 175
# Contact between bees 26 and 31 at frame 6: distance is 163.00306745579974, contact distance is 175
# Contact between bees 37 and 40 at frame 6: distance is 156.46085772486356, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 7: distance is 235.46761985462035, contact distance is 236.25000000000003
# Contact between bees 13 and 43 at frame 7: distance is 166.19265928433782, contact distance is 175
# Contact between bees 15 and 39 at frame 7: distance is 154.35349040433132, contact distance is 175
# Contact between bees 22 and 39 at frame 7: distance is 173.2887763243771, contact distance is 175
# Contact between bees 26 and 31 at frame 7: distance is 161.11176245079065, contact distance is 175
# Contact between bees 37 and 40 at frame 7: distance is 151.24152868838638, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 8: distance is 221.96396103872357, contact distance is 236.25000000000003
# Contact between bees 13 and 43 at frame 8: distance is 138.70832707519762, contact distance is 175
# Contact between bees 26 and 31 at frame 8: distance is 168.8697723099075, contact distance is 175
# Contact between bees 37 and 40 at frame 8: distance is 152.84632805533798, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 9: distance is 215.3555200128383, contact distance is 236.25000000000003
# Contact between bees 13 and 43 at frame 9: distance is 134.6291201783626, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 10: distance is 218.81956036881164, contact distance is 236.25000000000003
# Contact between bees 10 and 21 at frame 10: distance is 155.8589105569521, contact distance is 175
# Contact between bees 13 and 43 at frame 10: distance is 157.68956845650888, contact distance is 175
# Contact between bees 18 and 25 at frame 10: distance is 156.92354826475216, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 11: distance is 226.59214461229675, contact distance is 236.25000000000003
# Contact between bees 18 and 44 at frame 11: distance is 160.9534094078159, contact distance is 175
# Contact between bees 34 and 47 at frame 11: distance is 146.01369798755184, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 12: distance is 225.43513479491168, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 12: distance is 215.03720608304042, contact distance is 236.25000000000003
# Contact between bees 18 and 44 at frame 12: distance is 164.5600194457937, contact distance is 175
# Contact between bees 34 and 47 at frame 12: distance is 95.42536350467836, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 13: distance is 187.2591786802452, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 13: distance is 218.908656749796, contact distance is 236.25000000000003
# Contact between bees 34 and 47 at frame 13: distance is 113.21660655575224, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 14: distance is 176.63804799646084, contact distance is 236.25000000000003
# Contact between bees 34 and 47 at frame 14: distance is 143.56183336806478, contact distance is 175
# Contact between bees 0 and 4 at frame 15: distance is 131.73458164050928, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 15: distance is 226.645097012929, contact distance is 236.25000000000003
# Contact between bees 6 and 31 at frame 15: distance is 160.65490966665163, contact distance is 175
# Contact between bees 7 and 36 at frame 15: distance is 160.0781059358212, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 16: distance is 146.03081866510234, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 16: distance is 232.4908600354001, contact distance is 236.25000000000003
# Contact between bees 7 and 36 at frame 16: distance is 154.69001260585637, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 17: distance is 149.2816130673835, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 17: distance is 225.5770378385176, contact distance is 236.25000000000003
# Contact between bees 7 and 36 at frame 17: distance is 140.61649974309557, contact distance is 175
# Contact between bees 0 and 4 at frame 18: distance is 159.47727110782904, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 18: distance is 226.38462845343543, contact distance is 236.25000000000003
# Contact between bees 8 and 49 at frame 18: distance is 126.69648771769484, contact distance is 175
# Contact between bees 13 and 39 at frame 18: distance is 141.76741515595182, contact distance is 175
# Contact between bees 34 and 49 at frame 18: distance is 169.0562036720333, contact distance is 175
# Contact between bees 0 and 4 at frame 19: distance is 148.27339613025663, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 19: distance is 222.89459392277777, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 19: distance is 168.34488409215172, contact distance is 175
# Contact between bees 0 and 4 at frame 20: distance is 138.00362314084367, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 20: distance is 226.13491548188662, contact distance is 236.25000000000003
# Contact between bees 0 and 4 at frame 21: distance is 164.01219466856725, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 21: distance is 209.84756372185979, contact distance is 236.25000000000003
# Contact between bees 26 and 31 at frame 21: distance is 169.00887550658396, contact distance is 175
# Contact between bees 41 and 44 at frame 21: distance is 171.09354166653983, contact distance is 175
# Contact between bees 0 and 4 at frame 22: distance is 165.00303027520434, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 22: distance is 101.35580891098448, contact distance is 175
# Contact between bees 41 and 44 at frame 22: distance is 69.06518659932803, contact distance is 175
# Contact between bees 0 and 4 at frame 23: distance is 167.0029939851379, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 23: distance is 77.6659513557904, contact distance is 175
# Contact between bees 41 and 44 at frame 23: distance is 158.31929762350515, contact distance is 175
# Contact between bees 0 and 4 at frame 24: distance is 172.4905794529081, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 24: distance is 83.6301381082203, contact distance is 175
# Contact between bees 0 and 4 at frame 25: distance is 170.75128110793196, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 25: distance is 99.62429422585637, contact distance is 175
# Contact between bees 0 and 4 at frame 26: distance is 160.70158679988197, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 26: distance is 104.1393297462587, contact distance is 175
# Contact between bees 0 and 4 at frame 27: distance is 143.78456106272327, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 27: distance is 231.4821807396846, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 27: distance is 112.29425630903836, contact distance is 175
# Contact between bees 18 and 41 at frame 27: distance is 130.75167302944922, contact distance is 175
# Contact between bees 34 and 36 at frame 27: distance is 168.30923919975396, contact distance is 175
# Contact between bees 0 and 4 at frame 28: distance is 136.5283853270081, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 28: distance is 234.0939982143925, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 28: distance is 200.6913052426537, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 28: distance is 166.41213898030395, contact distance is 175
# Contact between bees 18 and 38 at frame 28: distance is 150.23315213360866, contact distance is 175
# Contact between bees 18 and 41 at frame 28: distance is 147.85127662620977, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 29: distance is 130.31116606031887, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 29: distance is 232.38115241989829, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 29: distance is 197.12432625122653, contact distance is 236.25000000000003
# Contact between bees 1 and 45 at frame 29: distance is 158.8238017426859, contact distance is 175
# Contact between bees 13 and 39 at frame 29: distance is 173.63179432350518, contact distance is 175
# Contact between bees 18 and 38 at frame 29: distance is 144.30869689661813, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 30: distance is 128.47178678604885, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 30: distance is 234.6422809299296, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 30: distance is 193.6620768245554, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 30: distance is 139.08630414242805, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 31: distance is 137.44089638822936, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 31: distance is 192.62917743685665, contact distance is 236.25000000000003
# Contact between bees 7 and 34 at frame 31: distance is 152.97058540778355, contact distance is 175
# Contact between bees 18 and 38 at frame 31: distance is 114.33722053644648, contact distance is 175
# Contact between bees 0 and 4 at frame 32: distance is 149.85659811966906, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 32: distance is 200.44201156444225, contact distance is 236.25000000000003
# Contact between bees 7 and 34 at frame 32: distance is 157.1146078504478, contact distance is 175
# Contact between bees 18 and 38 at frame 32: distance is 103.00485425454472, contact distance is 175
# Contact between bees 0 and 4 at frame 33: distance is 155.54099138169335, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 33: distance is 214.03737991294884, contact distance is 236.25000000000003
# Contact between bees 7 and 34 at frame 33: distance is 167.6722994414999, contact distance is 175
# Contact between bees 18 and 38 at frame 33: distance is 119.50313803411188, contact distance is 175
# Contact between bees 0 and 4 at frame 34: distance is 164.46884203398528, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 34: distance is 220.22715545545242, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 34: distance is 114.40279716860073, contact distance is 175
# Contact between bees 0 and 4 at frame 35: distance is 179.74426277353055, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 35: distance is 223.503914954526, contact distance is 236.25000000000003
# Contact between bees 4 and 38 at frame 35: distance is 144.64093473149293, contact distance is 175
# Contact between bees 18 and 38 at frame 35: distance is 126.49110640673517, contact distance is 175
# Contact between bees 0 and 4 at frame 36: distance is 171.40595088852663, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 36: distance is 229.83907413666634, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 36: distance is 226.3183598385248, contact distance is 236.25000000000003
# Contact between bees 4 and 38 at frame 36: distance is 162.265215003093, contact distance is 175
# Contact between bees 13 and 39 at frame 36: distance is 173.0664612222715, contact distance is 175
# Contact between bees 18 and 38 at frame 36: distance is 129.31357237351384, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 37: distance is 181.5543995611233, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 37: distance is 229.6366695456107, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 37: distance is 204.35263639111682, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 37: distance is 138.45215780189199, contact distance is 175
# Contact between bees 26 and 31 at frame 37: distance is 161.7188919081503, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 38: distance is 201.64572894063488, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 38: distance is 232.04525420701884, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 38: distance is 218.91550881561588, contact distance is 236.25000000000003
# Contact between bees 18 and 38 at frame 38: distance is 144.5441109142811, contact distance is 175
# Contact between bees 26 and 31 at frame 38: distance is 162.5423021862309, contact distance is 175
# Contact between bees 34 and 36 at frame 38: distance is 173.5655495770978, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 39: distance is 208.58571379651102, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 39: distance is 169.07099100673656, contact distance is 175
# Contact between bees 18 and 38 at frame 39: distance is 148.6371420607918, contact distance is 175
# Contact between bees 26 and 31 at frame 39: distance is 162.28986413205232, contact distance is 175
# Contact between bees 34 and 36 at frame 39: distance is 154.46682491719702, contact distance is 175
# Contact between bees 0 and 4 at frame 40: distance is 182.7840255602223, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 40: distance is 229.8173187555716, contact distance is 236.25000000000003
# Contact between bees 8 and 49 at frame 40: distance is 172.8120366178236, contact distance is 175
# Contact between bees 13 and 39 at frame 40: distance is 172.03778654702577, contact distance is 175
# Contact between bees 18 and 38 at frame 40: distance is 150.0966355385756, contact distance is 175
# Contact between bees 26 and 31 at frame 40: distance is 164.50227961946302, contact distance is 175
# Contact between bees 34 and 36 at frame 40: distance is 156.00320509528, contact distance is 175
# Contact between bees 41 and 47 at frame 40: distance is 167.0748335327616, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 41: distance is 163.95731151735808, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 41: distance is 174.20103329199858, contact distance is 175
# Contact between bees 18 and 38 at frame 41: distance is 167.1944975171133, contact distance is 175
# Contact between bees 26 and 31 at frame 41: distance is 164.50227961946302, contact distance is 175
# Contact between bees 34 and 36 at frame 41: distance is 165.38742394752995, contact distance is 175
# Contact between bees 41 and 47 at frame 41: distance is 131.0953851209111, contact distance is 175
# Contact between bees 0 and 4 at frame 42: distance is 151.42654985173505, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 42: distance is 162.68988905276197, contact distance is 175
# Contact between bees 26 and 31 at frame 42: distance is 162.63148526653748, contact distance is 175
# Contact between bees 0 and 4 at frame 43: distance is 139.74262055650738, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 43: distance is 134.35773144854747, contact distance is 175
# Contact between bees 13 and 39 at frame 43: distance is 164.76953601925328, contact distance is 175
# Contact between bees 26 and 31 at frame 43: distance is 161.40012391568973, contact distance is 175
# Contact between bees 0 and 4 at frame 44: distance is 158.00316452527144, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 44: distance is 127.80062597655773, contact distance is 175
# Contact between bees 13 and 39 at frame 44: distance is 161.19863522995473, contact distance is 175
# Contact between bees 14 and 42 at frame 44: distance is 171.1286066091815, contact distance is 175
# Contact between bees 26 and 31 at frame 44: distance is 163.67040050051813, contact distance is 175
# Contact between bees 0 and 4 at frame 45: distance is 144.99655168313487, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 45: distance is 110.46266337545913, contact distance is 175
# Contact between bees 14 and 42 at frame 45: distance is 149.84325143295575, contact distance is 175
# Contact between bees 26 and 31 at frame 45: distance is 161.07451691686057, contact distance is 175
# Contact between bees 0 and 4 at frame 46: distance is 153.37861650177967, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 46: distance is 229.49074055394914, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 46: distance is 112.50777750893491, contact distance is 175
# Contact between bees 14 and 42 at frame 46: distance is 112.61438629233834, contact distance is 175
# Contact between bees 26 and 31 at frame 46: distance is 159.928108848945, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 47: distance is 143.54441821262157, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 47: distance is 222.40953216982405, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 47: distance is 105.09519494249011, contact distance is 175
# Contact between bees 14 and 42 at frame 47: distance is 109.83624174196785, contact distance is 175
# Contact between bees 26 and 31 at frame 47: distance is 156.0833110873805, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 48: distance is 146.21901381147393, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 48: distance is 217.3660507070964, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 48: distance is 97.57561170702442, contact distance is 175
# Contact between bees 14 and 42 at frame 48: distance is 106.47065323364932, contact distance is 175
# Contact between bees 26 and 31 at frame 48: distance is 155.97435686676192, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 49: distance is 188.48076824970764, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 49: distance is 213.92755783208483, contact distance is 236.25000000000003
# Contact between bees 1 and 11 at frame 49: distance is 167.0359242797788, contact distance is 175
# Contact between bees 6 and 45 at frame 49: distance is 102.82509421342633, contact distance is 175
# Contact between bees 7 and 34 at frame 49: distance is 173.76996288196645, contact distance is 175
# Contact between bees 14 and 42 at frame 49: distance is 103.07764064044152, contact distance is 175
# Contact between bees 26 and 31 at frame 49: distance is 159.15401345866212, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 50: distance is 196.7587355112855, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 50: distance is 212.6405417600322, contact distance is 236.25000000000003
# Contact between bees 1 and 11 at frame 50: distance is 165.4962235218677, contact distance is 175
# Contact between bees 6 and 45 at frame 50: distance is 114.5294721894762, contact distance is 175
# Contact between bees 14 and 42 at frame 50: distance is 102.7861858422619, contact distance is 175
# Contact between bees 26 and 31 at frame 50: distance is 158.67261893597143, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 51: distance is 193.28993765843063, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 51: distance is 212.8497122384712, contact distance is 236.25000000000003
# Contact between bees 1 and 11 at frame 51: distance is 169.92056967889437, contact distance is 175
# Contact between bees 6 and 45 at frame 51: distance is 119.01680553602503, contact distance is 175
# Contact between bees 14 and 42 at frame 51: distance is 102.18121158021175, contact distance is 175
# Contact between bees 26 and 31 at frame 51: distance is 159.20113064925135, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 52: distance is 193.94071259021402, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 52: distance is 214.2265156324025, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 52: distance is 109.01834707974616, contact distance is 175
# Contact between bees 8 and 41 at frame 52: distance is 143.8923208513922, contact distance is 175
# Contact between bees 14 and 42 at frame 52: distance is 102.59142264341595, contact distance is 175
# Contact between bees 26 and 31 at frame 52: distance is 160.80111939908875, contact distance is 175
# Contact between bees 41 and 49 at frame 52: distance is 156.32018423735306, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 53: distance is 207.63429389192913, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 53: distance is 202.05444810743464, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 53: distance is 125.57467897629681, contact distance is 175
# Contact between bees 8 and 41 at frame 53: distance is 125.87692401707312, contact distance is 175
# Contact between bees 14 and 42 at frame 53: distance is 85.16454661418682, contact distance is 175
# Contact between bees 26 and 31 at frame 53: distance is 161.20794025109308, contact distance is 175
# Contact between bees 41 and 49 at frame 53: distance is 128.94960255851896, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 54: distance is 220.4835594777987, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 54: distance is 202.03217565526538, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 54: distance is 133.55523202031435, contact distance is 175
# Contact between bees 14 and 42 at frame 54: distance is 91.35097153287424, contact distance is 175
# Contact between bees 26 and 31 at frame 54: distance is 166.83225107874077, contact distance is 175
# Contact between bees 41 and 49 at frame 54: distance is 101.24228365658294, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 55: distance is 188.4887264533346, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 55: distance is 207.29930052945187, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 55: distance is 138.4629914453678, contact distance is 175
# Contact between bees 14 and 42 at frame 55: distance is 83.15046602394962, contact distance is 175
# Contact between bees 26 and 31 at frame 55: distance is 168.24089871371942, contact distance is 175
# Contact between bees 41 and 49 at frame 55: distance is 131.4838393111488, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 56: distance is 198.8793604173143, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 56: distance is 214.04905979704745, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 56: distance is 139.26952286842948, contact distance is 175
# Contact between bees 14 and 42 at frame 56: distance is 87.13208364316786, contact distance is 175
# Contact between bees 15 and 34 at frame 56: distance is 134.12307780542466, contact distance is 175
# Contact between bees 26 and 31 at frame 56: distance is 166.35203635663737, contact distance is 175
# Contact between bees 41 and 49 at frame 56: distance is 154.11683879446787, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 57: distance is 193.82982226685345, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 57: distance is 234.88720697390056, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 57: distance is 119.60351165413162, contact distance is 175
# Contact between bees 14 and 42 at frame 57: distance is 96.20810776644555, contact distance is 175
# Contact between bees 26 and 31 at frame 57: distance is 166.97305171793442, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 58: distance is 203.8062805705457, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 58: distance is 106.07544484940895, contact distance is 175
# Contact between bees 14 and 42 at frame 58: distance is 93.14504817756014, contact distance is 175
# Contact between bees 26 and 31 at frame 58: distance is 173.51080657987848, contact distance is 175
# Contact between bees 0 and 4 at frame 59: distance is 198.92712233378333, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 59: distance is 195.1665955024066, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 59: distance is 113.11056537742175, contact distance is 175
# Contact between bees 14 and 42 at frame 59: distance is 89.80534505250787, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 60: distance is 198.08079159777205, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 60: distance is 195.5326059765992, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 60: distance is 128.51459061133875, contact distance is 175
# Contact between bees 7 and 41 at frame 60: distance is 168.32409215557945, contact distance is 175
# Contact between bees 14 and 42 at frame 60: distance is 88.0056816347672, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 61: distance is 203.59273071502332, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 61: distance is 189.08199279677586, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 61: distance is 127.58134659894448, contact distance is 175
# Contact between bees 7 and 41 at frame 61: distance is 120.83045973594572, contact distance is 175
# Contact between bees 14 and 42 at frame 61: distance is 109.60383204979651, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 62: distance is 209.61870145576228, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 62: distance is 194.64840096954302, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 62: distance is 129.20139318134306, contact distance is 175
# Contact between bees 7 and 41 at frame 62: distance is 160.099968769516, contact distance is 175
# Contact between bees 14 and 42 at frame 62: distance is 151.85519418182574, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 4 at frame 63: distance is 220.49263026232873, contact distance is 236.25000000000003
# Contact between bees 0 and 17 at frame 63: distance is 200.44201156444225, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 63: distance is 137.90576492663388, contact distance is 175
# Contact between bees 14 and 42 at frame 63: distance is 158.25612152457168, contact distance is 175
# Contact between bees 22 and 34 at frame 63: distance is 122.11470017978998, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 64: distance is 220.00909072126996, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 64: distance is 110.16351483136329, contact distance is 175
# Contact between bees 14 and 42 at frame 64: distance is 163.63679292872982, contact distance is 175
# Contact between bees 15 and 41 at frame 64: distance is 114.49017425089369, contact distance is 175
# Contact between bees 22 and 34 at frame 64: distance is 163.21764610482532, contact distance is 175
# contact for bee 17
# Contact between bees 6 and 45 at frame 65: distance is 104.08650248711405, contact distance is 175
# Contact between bees 14 and 42 at frame 65: distance is 147.41099009232656, contact distance is 175
# Contact between bees 15 and 41 at frame 65: distance is 149.093930124603, contact distance is 175
# Contact between bees 6 and 45 at frame 66: distance is 126.21014222319853, contact distance is 175
# Contact between bees 14 and 42 at frame 66: distance is 134.35773144854747, contact distance is 175
# Contact between bees 6 and 45 at frame 67: distance is 135.72398461583714, contact distance is 175
# Contact between bees 14 and 42 at frame 67: distance is 129.72663566130126, contact distance is 175
# Contact between bees 1 and 24 at frame 68: distance is 165.22106403240477, contact distance is 175
# Contact between bees 6 and 45 at frame 68: distance is 170.41713528867922, contact distance is 175
# Contact between bees 14 and 42 at frame 68: distance is 124.80785231707178, contact distance is 175
# Contact between bees 1 and 24 at frame 69: distance is 150.136604464068, contact distance is 175
# Contact between bees 7 and 44 at frame 69: distance is 169.28378540191025, contact distance is 175
# Contact between bees 11 and 40 at frame 69: distance is 171.42053552593984, contact distance is 175
# Contact between bees 14 and 42 at frame 69: distance is 120.9297316626478, contact distance is 175
# Contact between bees 15 and 20 at frame 69: distance is 156.97770542341354, contact distance is 175
# Contact between bees 1 and 24 at frame 70: distance is 143.58969322343438, contact distance is 175
# Contact between bees 7 and 44 at frame 70: distance is 142.66744548074027, contact distance is 175
# Contact between bees 9 and 41 at frame 70: distance is 150.2131818450032, contact distance is 175
# Contact between bees 11 and 40 at frame 70: distance is 152.95751043999115, contact distance is 175
# Contact between bees 14 and 42 at frame 70: distance is 117.47765745025733, contact distance is 175
# Contact between bees 15 and 20 at frame 70: distance is 152.74161188098023, contact distance is 175
# Contact between bees 1 and 24 at frame 71: distance is 152.81688388394784, contact distance is 175
# Contact between bees 6 and 45 at frame 71: distance is 162.8649747490233, contact distance is 175
# Contact between bees 7 and 44 at frame 71: distance is 153.88307249337075, contact distance is 175
# Contact between bees 11 and 40 at frame 71: distance is 130.3878828726044, contact distance is 175
# Contact between bees 14 and 42 at frame 71: distance is 114.93476410555685, contact distance is 175
# Contact between bees 0 and 43 at frame 72: distance is 235.49309968659378, contact distance is 236.25000000000003
# Contact between bees 1 and 24 at frame 72: distance is 173.4156855650607, contact distance is 175
# Contact between bees 6 and 45 at frame 72: distance is 160.85397104206038, contact distance is 175
# Contact between bees 7 and 44 at frame 72: distance is 156.52475842498527, contact distance is 175
# Contact between bees 14 and 42 at frame 72: distance is 111.61541112229978, contact distance is 175
# Contact between bees 0 and 43 at frame 73: distance is 232.0, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 73: distance is 146.16771189288008, contact distance is 175
# Contact between bees 7 and 44 at frame 73: distance is 156.66843970627906, contact distance is 175
# Contact between bees 14 and 42 at frame 73: distance is 110.3675676999362, contact distance is 175
# Contact between bees 34 and 41 at frame 73: distance is 148.7615541731129, contact distance is 175
# Contact between bees 0 and 43 at frame 74: distance is 220.62184841941652, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 74: distance is 155.08062419270823, contact distance is 175
# Contact between bees 7 and 44 at frame 74: distance is 144.40221604947757, contact distance is 175
# Contact between bees 34 and 41 at frame 74: distance is 158.47397262642215, contact distance is 175
# Contact between bees 0 and 43 at frame 75: distance is 215.07673049402624, contact distance is 236.25000000000003
# Contact between bees 6 and 45 at frame 75: distance is 167.08381130438698, contact distance is 175
# Contact between bees 7 and 44 at frame 75: distance is 146.12323566086263, contact distance is 175
# Contact between bees 0 and 43 at frame 76: distance is 193.34942461771124, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 76: distance is 173.1415605797753, contact distance is 175
# Contact between bees 0 and 43 at frame 77: distance is 183.2184488527288, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 77: distance is 174.0028735394907, contact distance is 175
# Contact between bees 0 and 43 at frame 78: distance is 183.8069639594757, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 79: distance is 202.00247523235947, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 79: distance is 170.07351351694948, contact distance is 175
# Contact between bees 0 and 43 at frame 80: distance is 208.96889720721597, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 80: distance is 162.8649747490233, contact distance is 175
# Contact between bees 35 and 44 at frame 80: distance is 100.4987562112089, contact distance is 175
# Contact between bees 0 and 43 at frame 81: distance is 228.0350850198276, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 81: distance is 151.00331122197287, contact distance is 175
# Contact between bees 13 and 39 at frame 81: distance is 164.5600194457937, contact distance is 175
# Contact between bees 35 and 38 at frame 81: distance is 120.70211265756701, contact distance is 175
# Contact between bees 0 and 17 at frame 82: distance is 223.503914954526, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 82: distance is 122.98373876248843, contact distance is 175
# Contact between bees 13 and 39 at frame 82: distance is 162.3884232326923, contact distance is 175
# Contact between bees 35 and 38 at frame 82: distance is 119.01680553602503, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 83: distance is 227.8815481779953, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 83: distance is 228.07893370497854, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 83: distance is 153.63918770938616, contact distance is 175
# Contact between bees 13 and 39 at frame 83: distance is 169.06803364326444, contact distance is 175
# Contact between bees 35 and 38 at frame 83: distance is 145.2205219657332, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 17 at frame 84: distance is 227.6532450899833, contact distance is 236.25000000000003
# Contact between bees 0 and 43 at frame 84: distance is 213.33541665649423, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 84: distance is 147.1767644704829, contact distance is 175
# Contact between bees 13 and 39 at frame 84: distance is 164.13713778423212, contact distance is 175
# Contact between bees 35 and 38 at frame 84: distance is 164.43843832875572, contact distance is 175
# contact for bee 17
# Contact between bees 0 and 43 at frame 85: distance is 201.0198995124612, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 85: distance is 159.40200751558933, contact distance is 175
# Contact between bees 13 and 39 at frame 85: distance is 152.59423318068085, contact distance is 175
# Contact between bees 35 and 38 at frame 85: distance is 154.00324671902212, contact distance is 175
# Contact between bees 0 and 43 at frame 86: distance is 209.990475974507, contact distance is 236.25000000000003
# Contact between bees 9 and 34 at frame 86: distance is 171.0263137648707, contact distance is 175
# Contact between bees 13 and 39 at frame 86: distance is 151.71684151734772, contact distance is 175
# Contact between bees 35 and 38 at frame 86: distance is 150.00333329629711, contact distance is 175
# Contact between bees 0 and 43 at frame 87: distance is 205.65018842685265, contact distance is 236.25000000000003
# Contact between bees 13 and 39 at frame 87: distance is 151.09268678529745, contact distance is 175
# Contact between bees 35 and 38 at frame 87: distance is 127.00393694685216, contact distance is 175
# Contact between bees 39 and 41 at frame 87: distance is 173.95401691251627, contact distance is 175
# Contact between bees 0 and 43 at frame 88: distance is 215.37177159507232, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 88: distance is 150.7912464302885, contact distance is 175
# Contact between bees 13 and 39 at frame 88: distance is 163.29421300217592, contact distance is 175
# Contact between bees 35 and 38 at frame 88: distance is 112.36102527122117, contact distance is 175
# Contact between bees 0 and 43 at frame 89: distance is 221.65062598603234, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 89: distance is 154.18495387034366, contact distance is 175
# Contact between bees 13 and 39 at frame 89: distance is 167.29913329123974, contact distance is 175
# Contact between bees 35 and 38 at frame 89: distance is 125.06398362438324, contact distance is 175
# Contact between bees 0 and 43 at frame 90: distance is 218.3437656540713, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 90: distance is 163.1349134918703, contact distance is 175
# Contact between bees 13 and 39 at frame 90: distance is 166.48123017325406, contact distance is 175
# Contact between bees 35 and 38 at frame 90: distance is 145.41664278891878, contact distance is 175
# Contact between bees 0 and 43 at frame 91: distance is 221.29844102478444, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 91: distance is 143.54441821262157, contact distance is 175
# Contact between bees 13 and 39 at frame 91: distance is 161.3071604114337, contact distance is 175
# Contact between bees 35 and 38 at frame 91: distance is 124.90396310766124, contact distance is 175
# Contact between bees 0 and 43 at frame 92: distance is 219.1118435867856, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 92: distance is 138.7984149765407, contact distance is 175
# Contact between bees 13 and 39 at frame 92: distance is 159.42396306703708, contact distance is 175
# Contact between bees 35 and 38 at frame 92: distance is 113.3225485064645, contact distance is 175
# Contact between bees 0 and 43 at frame 93: distance is 217.22108553268947, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 93: distance is 162.01234520862909, contact distance is 175
# Contact between bees 9 and 36 at frame 93: distance is 147.2582765076381, contact distance is 175
# Contact between bees 13 and 39 at frame 93: distance is 162.64070831129578, contact distance is 175
# Contact between bees 35 and 38 at frame 93: distance is 114.33722053644648, contact distance is 175
# Contact between bees 0 and 43 at frame 94: distance is 218.52459815773602, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 94: distance is 162.43152403397562, contact distance is 175
# Contact between bees 9 and 36 at frame 94: distance is 141.03900169811186, contact distance is 175
# Contact between bees 13 and 39 at frame 94: distance is 159.8311609167624, contact distance is 175
# Contact between bees 35 and 38 at frame 94: distance is 119.85407794480753, contact distance is 175
# Contact between bees 0 and 43 at frame 95: distance is 232.26278221015093, contact distance is 236.25000000000003
# Contact between bees 7 and 44 at frame 95: distance is 151.85519418182574, contact distance is 175
# Contact between bees 9 and 36 at frame 95: distance is 163.88410539158457, contact distance is 175
# Contact between bees 13 and 39 at frame 95: distance is 145.71547618561317, contact distance is 175
# Contact between bees 35 and 38 at frame 95: distance is 81.09870529176159, contact distance is 175
# Contact between bees 9 and 36 at frame 96: distance is 166.6283289239858, contact distance is 175
# Contact between bees 13 and 39 at frame 96: distance is 134.72935834479432, contact distance is 175
# Contact between bees 35 and 38 at frame 96: distance is 59.93329625508679, contact distance is 175
# Contact between bees 7 and 44 at frame 97: distance is 153.8083222715858, contact distance is 175
# Contact between bees 13 and 39 at frame 97: distance is 143.0, contact distance is 175
# Contact between bees 18 and 35 at frame 97: distance is 159.67780058605516, contact distance is 175
# Contact between bees 20 and 34 at frame 97: distance is 162.01234520862909, contact distance is 175
# Contact between bees 35 and 38 at frame 97: distance is 46.14108798023731, contact distance is 175
# Contact between bees 7 and 44 at frame 98: distance is 144.49913494550754, contact distance is 175
# Contact between bees 13 and 39 at frame 98: distance is 136.61991070118586, contact distance is 175
# Contact between bees 18 and 35 at frame 98: distance is 145.89036979869508, contact distance is 175
# Contact between bees 20 and 34 at frame 98: distance is 129.2594290564522, contact distance is 175
# Contact between bees 35 and 38 at frame 98: distance is 51.62363799656123, contact distance is 175
# Contact between bees 7 and 44 at frame 99: distance is 148.55302083767936, contact distance is 175
# Contact between bees 13 and 39 at frame 99: distance is 138.6542462386205, contact distance is 175
# Contact between bees 18 and 35 at frame 99: distance is 169.0266251216062, contact distance is 175
# Contact between bees 35 and 38 at frame 99: distance is 61.587336360651285, contact distance is 175
# Done! Frames should be written to video.

# %%
#This portion of the code focuses on drawing the centroids of potential tag IDs, for error checking purposes
'''
def draw_noID_centroids(frame, frame_df):
    
    for index, row in frame_df.iterrows():
    
        xmean = row['centroidX'] #int(ser.iloc[0])
        xmean = int(xmean)
        ymean = row['centroidY']
        ymean = int(ymean)
    
        
        cv2.circle(frame, tuple([int(xmean), int(ymean)]), 20, (0,0,255), -1)

        return frame

# Draw noIDs onto video to show the bees that were not detected in the frame
noID_path = '/home/august/Desktop/Human Footprint/bumblebox-11_2024-08-27_01_20_03_noID.csv'
video_path = '/home/august/Desktop/Human Footprint/bumblebox-11_2024-08-27_01_20_03_tracked.mp4'
noID_filename_addition = '_noID_tracked'
noID_destination_directory = '/home/august/Desktop/Human Footprint/'
write_noID_video = 'ON'
show_noID_video = 'OFF'
noID_playback_framerate = 6


   #read in csv data and video
df = pd.read_csv(noID_path)
vid = cv2.VideoCapture(video_path)
   
    #extract filename and extension from video path
filename, extension = extract_filename(video_path)

size = extract_size(vid)
out = create_outputfile_and_videowriter(noID_destination_directory, filename, noID_filename_addition, extension, noID_playback_framerate, size)

frame_num = 0

while(vid.isOpened()):
        ret, frame = vid.read() #ret stores boolean, frame stores the frame -code copied
        
        if ret == True:
            try:
                frame_df = df[ df['frame'] == frame_num ]

                for row in frame_df:
                     frame = draw_noID_centroids(frame, frame_df)
                
            except Exception as e:
                print_error_message(e)
            
            #now just writing and showing the frame
            if write_noID_video == 'ON':
                out.write(frame)

            if show_noID_video == 'ON':
                cv2.imshow("Let's track these bees! Beep boop", frame)
    
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            else:
                cv2.waitKey(1)
            
            frame_num += 1

        #if ret is false, ie no more frames to read, break out of loop
        else:
            frame_num += 1
            break

# Release everything once job is finished
print("Done! Frames should be written to video.")
vid.release()
cv2.destroyAllWindows()

'''
# Out:
# bumblebox-11_2024-08-27_01_20_03_tracked
# write_video is on
# /home/august/Desktop/Human Footprint/bumblebox-11_2024-08-27_01_20_03_tracked_noID_tracked.mp4
# Done! Frames should be written to video.

# %%
'''
#ATTENTION! This portion of the code is to interpolate missing data in a csv file prior to creating
#tracked videos. You don't need to run this if you have already interpolated your data. In order to run this script, you need to have
#the data_cleaning.py file in the same directory as this script.

import data_cleaning
import pandas as pd
import numpy as np

csv_path = "/home/august/Desktop/Human Footprint/bumblebox-17_2025-02-14_17_30_03_tracking.csv"
interpolated_csv_path = '/home/august/Desktop/Human Footprint/bumblebox-17_2025-02-14_17_30_03_tracking_interpolated.csv'

max_seconds_gap = 2
actual_frames_per_second = 4.5

df = pd.read_csv(csv_path)
interpolated_df = data_cleaning.interpolate(df, max_seconds_gap, actual_frames_per_second)
interpolated_df = data_cleaning.remove_jumps(interpolated_df)
interpolated_csv_path = csv_path.replace('.csv', '_interpolated.csv')
interpolated_df.to_csv(interpolated_csv_path, index=False)

'''
